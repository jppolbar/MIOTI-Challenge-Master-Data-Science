# %% [markdown]
# # Recuperar variables de clasificadores
#
# Con pickle recuperamos solo las variables indicadas

# %% [markdown]
# ## Configuración del entorno

# %%
# %matplotlib inline

import warnings
warnings.filterwarnings("ignore")

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import sklearn
from sklearn.metrics import confusion_matrix
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import train_test_split

# %%
def dibuja_dataset(X, y):  
    from matplotlib.colors import ListedColormap
    cm_bright = ListedColormap(['#FF0000', '#0000FF'])
    plt.scatter(X[:,0], X[:, 1], c=y, cmap=cm_bright, edgecolors='k')

# %%
def dibuja_dataset2(X, y, Xnew, ynew):  
    from matplotlib.colors import ListedColormap
    cm_bright = ListedColormap(['#FF0000', '#0000FF'])
    plt.scatter(X[:,0], X[:, 1], c=y, cmap=cm_bright, edgecolors='k')
    plt.scatter(Xnew[:,0], Xnew[:, 1], c=ynew, cmap=cm_bright, edgecolors='k',marker='^', s = 200)

# %% [markdown]
# ## Recuperamos  las variables de la sesion anterior

# %%
import pickle

# abrir fichero
file = open('bck_var_pickle_modelo1.pkl', 'rb')

# cargar las variables desde el fichero
modelo_entrenado, dataset_X, dataset_y = pickle.load(file)

# close the file
file.close()

# %%
dibuja_dataset(dataset_X, dataset_y)

# %% [markdown]
# #### Las variables no guardadas no se recuperan

# %%
dibuja_dataset2(dataset_X, dataset_y,test_samples,y_hat_samples)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-6-06b87f8c9e3a> in <module>
# ----> 1 dibuja_dataset2(dataset_X, dataset_y,test_samples,y_hat_samples)
#
# NameError: name 'test_samples' is not defined

# %% [markdown]
# ### Predecir dos nuevas muestras

# %%
test_samples2= np.array([[-1.5,0.],[2,1.5]])

# obtenemos la prediccion con el clasificador entrenado en la sesion anterior
y_hat_samples2 = modelo_entrenado.predict(test_samples2)
y_hat_samples2
# Out:
# array([0, 1], dtype=int64)

# %%
dibuja_dataset2(dataset_X, dataset_y,test_samples2,y_hat_samples2)
