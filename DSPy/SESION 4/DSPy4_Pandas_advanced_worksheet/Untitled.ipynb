# %%
import pandas as pd
import numpy as np

# %%
#data = pd.read_csv("C:/Users/JPAS/Downloads/Rango_Edades_Seccion_202103.csv",sep=';',encoding='ANSI')
data = pd.read_csv("C:/Users/JPAS/Downloads/MedioAmbiente_variacion_temperatura_S_Todos_los_Datos.csv",sep=',',encoding='ANSI')
data = pd.read_csv('C:/Users/JPAS/Downloads/Emisiones_Agricultura_Energia_S_Todos_los_Datos.csv',sep=',',encoding='ANSI')
data.head(10)
# Out:
#    Código área        Área  Código Producto                        Producto  \
# 0            2  Afganistán             6801                         Gasóleo
# 1            2  Afganistán             6801                         Gasóleo
# 2            2  Afganistán             6801                         Gasóleo
# 3            2  Afganistán             6800           Gasolina para motores
# 4            2  Afganistán             6800           Gasolina para motores
# 5            2  Afganistán             6800           Gasolina para motores
# 6            2  Afganistán             6802       Gas natural (incluso GNL)
# 7            2  Afganistán             6802       Gas natural (incluso GNL)
# 8            2  Afganistán             6802       Gas natural (incluso GNL)
# 9            2  Afganistán             6805  Gas licuado del petróleo (GLP)
#
#    Código Elemento                              Elemento Unidad     Y1970  \
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 14835 entries, 0 to 14834
# Columns: 105 entries, Código área to Y2018F
# dtypes: float64(49), int64(3), object(53)
# memory usage: 11.9+ MB

# %%
data.shape
# Out:
# (14835, 105)

# %%
data.describe(include=[np.float64])
# Out:
#               Y1970         Y1971         Y1972         Y1973         Y1974  \
# count  7.003000e+03  7.170000e+03  7.268000e+03  7.366000e+03  7.408000e+03
# mean   1.969277e+04  1.941245e+04  1.934397e+04  1.976289e+04  1.966255e+04
# std    5.911912e+04  5.958576e+04  6.104974e+04  6.684229e+04  6.568236e+04
# min    0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00
# 25%    1.500000e+00  1.500000e+00  1.490025e+00  1.500000e+00  1.500000e+00
# 50%    1.789200e+01  1.835755e+01  1.815845e+01  1.957330e+01  2.128150e+01
# 75%    3.316411e+03  2.973428e+03  2.862000e+03  3.262692e+03  3.543928e+03
# max    1.518825e+06  1.583012e+06  1.664922e+06  1.919934e+06  1.944767e+06
#
#               Y1975         Y1976         Y1977         Y1978         Y1979  \
# count  7.471000e+03  7.783000e+03  7.944000e+03  8.070000e+03  8.235000e+03
# mean   1.958483e+04  1.940067e+04  1.963350e+04  1.983019e+04  2.029587e+04
# ...

# %%
data2=data[(data['Área']=='Albania') & (data['Producto']=='Fueloil')]
data2
# Out:
#     Código área     Área  Código Producto Producto  Código Elemento  \
# 81            3  Albania             6804  Fueloil            72184
# 82            3  Albania             6804  Fueloil           719610
# 83            3  Albania             6804  Fueloil           722510
# 84            3  Albania             6804  Fueloil           724410
# 85            3  Albania             6804  Fueloil           719710
# 86            3  Albania             6804  Fueloil           723010
# 87            3  Albania             6804  Fueloil           724310
# 88            3  Albania             6804  Fueloil           719510
# 89            3  Albania             6804  Fueloil           719410
# 90            3  Albania             6804  Fueloil           723110
#
#                                           Elemento      Unidad    Y1970  \
# 81                          Consumo en agricultura   Terajulio      NaN
# 82            Factor de emisión implícito para CH4       kg/TJ     10.0
# ...
